# %%
import requests
import json

# %%
data = {'sqft_lot': 9000, 'sqft_living':1850, 'yr_built':1999, 'grade':10}
response= requests.post(' http://75ba-35-236-176-20.ngrok.io', json=data)
#print(json.dumps(response.json(), indent=2, ensure_ascii=False))

response.json()
# Out:
# {'estimated price': 641978.2000000001}
