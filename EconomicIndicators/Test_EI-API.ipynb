# %%
import requests
import json

# %%
periods = {'months_number': 12}
response= requests.post('http://88d3-34-148-255-77.ngrok.io', json=periods)
#print(json.dumps(response.json(), indent=2, ensure_ascii=False))

response.json()
# Out:
# {'last12': '{"2021-09-01T00:00:00Z":{"True_value":5.9},"2021-10-01T00:00:00Z":{"True_value":6.8},"2021-11-01T00:00:00Z":{"True_value":7.8},"2021-12-01T00:00:00Z":{"True_value":8.6},"2022-01-01T00:00:00Z":{"True_value":9.4},"2022-02-01T00:00:00Z":{"True_value":8.5},"2022-03-01T00:00:00Z":{"True_value":11.0},"2022-04-01T00:00:00Z":{"True_value":12.4},"2022-05-01T00:00:00Z":{"True_value":13.9},"2022-06-01T00:00:00Z":{"True_value":15.5},"2022-07-01T00:00:00Z":{"True_value":15.6},"2022-08-01T00:00:00Z":{"True_value":16.1}}',
# ...
